# %%
import pandas as pd
from pathlib import Path
import os

# %%
root_path = str(Path(os.path.abspath('')).parents[1])
event_info_path = os.path.join(root_path, 'data/data_transformed/event_info.csv')
result_values_path = os.path.join(root_path, 'data/data_transformed/result_values.csv')
result_units_path = os.path.join(root_path, 'data/data_transformed/result_units.csv')


event_info_df = pd.read_csv(event_info_path, sep=';')
result_values_df = pd.read_csv(result_values_path, sep=';', encoding='latin1')
result_units_df = pd.read_csv(result_units_path, sep=';')

event_info_df.head(10)
# Out:
#    year            competition_name          event_name  distance  time_limit  \
# 0  2002  Arnold Strongman Challenge    Apollon's Wheels       NaN         NaN
# 1  2002  Arnold Strongman Challenge        Max Deadlift       NaN         NaN
# 2  2002  Arnold Strongman Challenge         Hummer Push      12.0         NaN
# 3  2002  Arnold Strongman Challenge        Timber Carry      11.0         NaN
# 4  2003    Arnold's Strength Summit    Apollon's Wheels       NaN         NaN
# 5  2003    Arnold's Strength Summit        Max Deadlift       NaN         NaN
# 6  2003    Arnold's Strength Summit  Medicine Ball Toss       NaN         NaN
# 7  2003    Arnold's Strength Summit        Timber Carry      11.0         NaN
# 8  2004      Arnold's Strongest Man    Apollon's Wheels       NaN         NaN
# 9  2004      Arnold's Strongest Man        Max Deadlift       NaN         NaN
#
#   main_measurement_unit second_measurement_unit  min_weight  max_weight  \
# ...

# %%
event_info_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2342 entries, 0 to 2341
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     2342 non-null   int64
#  1   competition_name         2342 non-null   object
#  2   event_name               2342 non-null   object
#  3   distance                 629 non-null    float64
#  4   time_limit               1481 non-null   float64
#  5   main_measurement_unit    2191 non-null   object
#  6   second_measurement_unit  1214 non-null   object
#  7   min_weight               1954 non-null   float64
#  8   max_weight               1954 non-null   float64
#  9   weights                  1954 non-null   object
#  10  deadlift                 135 non-null    object
#  11  attempts                 14 non-null     float64
#  12  max_lifts                923 non-null    float64
#  13  lifts_num                0 non-null      float64
# ...

# %%
event_info_filtered_df = event_info_df[event_info_df['event_name']=="Timber Carry"]
event_info_filtered_df.head(30)
# Out:
#      year            competition_name    event_name  distance  time_limit  \
# 3    2002  Arnold Strongman Challenge  Timber Carry      11.0         NaN
# 7    2003    Arnold's Strength Summit  Timber Carry      11.0         NaN
# 12   2004      Arnold's Strongest Man  Timber Carry      11.0        30.0
# 18   2005      Arnold's Strongest Man  Timber Carry      11.0         NaN
# 19   2006    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 25   2007    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 31   2008    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 37   2009    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 47   2010    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 51   2011    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 57   2012    Arnold Strongman Classic  Timber Carry      11.0         NaN
# 64   2014    Arnold Strongman Classic  Timber Carry      11.0         NaN
# ...

# %%
result_values_df.describe()
# Out:
#               year  Apollon's Wheels  Max Deadlift  Hummer Push  Timber Carry  \
# count  3071.000000        126.000000    727.000000     8.000000    196.000000
# mean   2012.642462          2.357143    362.374140    18.962500      7.699184
# std       7.033411          2.174265    141.115717     4.469266      5.431979
# min    1986.000000          0.000000      0.000000    10.820000      0.000000
# 25%    2008.000000          0.000000    363.000000    17.482500      3.677500
# 50%    2014.000000          2.000000    400.000000    18.265000      7.385000
# 75%    2018.000000          4.000000    436.000000    21.310000     10.375000
# max    2024.000000          8.000000    549.000000    25.600000     24.820000
#
#        Medicine Ball Toss  Hammer Lift  Dumbbell Press  Weight Throw  \
# count           28.000000    20.000000      501.000000     56.000000
# mean             3.553214    14.637000        6.280878      4.135893
# ...

# %%
result_units_df.describe(include='all')
# Out:
#                year   competition_name competitor Apollon's Wheels  \
# count   3071.000000               3071       3071              121
# unique          NaN                 40        375                2
# top             NaN  WSM Final - group    B. Shaw             reps
# freq            NaN               1306         88               95
# mean    2012.642462                NaN        NaN              NaN
# std        7.033411                NaN        NaN              NaN
# min     1986.000000                NaN        NaN              NaN
# 25%     2008.000000                NaN        NaN              NaN
# 50%     2014.000000                NaN        NaN              NaN
# 75%     2018.000000                NaN        NaN              NaN
# max     2024.000000                NaN        NaN              NaN
#
#        Max Deadlift Hummer Push Timber Carry Medicine Ball Toss Hammer Lift  \
# count           640           8          187                 28          20
# ...

# %%
base_cols = ['year', 'competition_name', 'competitor']
result_units_filtered_df = result_units_df[base_cols+ ["Timber Carry"]]
result_units_filtered_df.head(30)
# Out:
#     year            competition_name       competitor Timber Carry
# 0   2002  Arnold Strongman Challenge         M. Henry            s
# 1   2002  Arnold Strongman Challenge       S. Karlsen            s
# 2   2002  Arnold Strongman Challenge       P. Pfister            s
# 3   2002  Arnold Strongman Challenge      M. Philippi            s
# 4   2002  Arnold Strongman Challenge     R. Bergmanis          NaN
# 5   2002  Arnold Strongman Challenge        A. Bolton            s
# 6   2002  Arnold Strongman Challenge    B. Gillingham          NaN
# 7   2002  Arnold Strongman Challenge    B. Schoonveld            s
# 8   2003    Arnold's Strength Summit     Å½. Savickas            s
# 9   2003    Arnold's Strength Summit       S. Karlsen            s
# 10  2003    Arnold's Strength Summit     R. Bergmanis            m
# 11  2003    Arnold's Strength Summit  M. Pudzianowski            m
# 12  2003    Arnold's Strength Summit         S. Kirit            m
# ...

# %%
result_values_df.head(5)
# Out:
#    year            competition_name    competitor  Apollon's Wheels  \
# 0  2002  Arnold Strongman Challenge      M. Henry               3.0
# 1  2002  Arnold Strongman Challenge    S. Karlsen               0.0
# 2  2002  Arnold Strongman Challenge    P. Pfister               3.0
# 3  2002  Arnold Strongman Challenge   M. Philippi               1.0
# 4  2002  Arnold Strongman Challenge  R. Bergmanis               1.0
#
#    Max Deadlift  Hummer Push  Timber Carry  Medicine Ball Toss  Hammer Lift  \
# 0         401.0        20.59         10.19                 NaN          NaN
# 1         352.0        17.62          9.50                 NaN          NaN
# 2         324.0        18.00          8.70                 NaN          NaN
# 3         374.0        18.53         20.84                 NaN          NaN
# 4         370.0        17.07          0.00                 NaN          NaN
#
#    Dumbbell Press  ...  Circle of Strength  Loading Medley  Pickaxe Hold  \
# ...

# %%
base_cols = ['year', 'competition_name', 'competitor']
event_name = 'Timber Carry'
unit = 's'
event_info_filter_col = 'max_weight'
all_cols = base_cols + [event_name] + ['unit'] + [event_info_filter_col]
result_values_filtered_df = result_values_df[base_cols + [event_name]]
result_values_filtered_df['unit']=result_units_df[event_name]
result_values_filtered_df = result_values_filtered_df.merge(event_info_df[event_info_df['event_name']=="Timber Carry"], on=['year', 'competition_name'], how='left')[all_cols]
# event_info_df[event_info_df['event_name']=="Timber Carry"]["max_weight"]
# result_values_filtered_df['weight']=

result_values_filtered_df = result_values_filtered_df[(result_values_filtered_df['unit']=='s') & (result_values_filtered_df['max_weight']==400)]
result_values_filtered_df = result_values_filtered_df.sort_values('Timber Carry')
result_values_filtered_df.head(30)
# Out:
# C:\Users\The God of Cringe\AppData\Local\Temp\ipykernel_21396\4169870953.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_values_filtered_df['unit']=result_units_df[event_name]
#      year          competition_name        competitor  Timber Carry unit  \
# 176  2020  Arnold Strongman Classic  M. Kieliszkowski          7.00    s
# 205  2024  Arnold Strongman Classic         M. Hooper          7.10    s
# 95   2012  Arnold Strongman Classic        M. Jenkins          7.42    s
# 96   2012  Arnold Strongman Classic     D. Poundstone          7.56    s
# 101  2012  Arnold Strongman Classic       L. Shahlaei          7.91    s
# 196  2023  Arnold Strongman Classic  M. Kieliszkowski          8.35    s
# ...
